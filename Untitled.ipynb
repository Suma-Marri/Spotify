# %% [markdown]
# Getting Access Tokens

# %%
import requests

CLIENT_ID = 'fcec7bdbea3d438f9a0b9158e82b057f'
CLIENT_SECRET = '63f31f01040647b5891953b97a3fbee2'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
r = r.json()
r
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
r = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers)

# %%
r = r.json()
r
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#     'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#     'id': '6nxWCVXbOlEVRexSbLsTer',
#     'name': 'Flume',
#     'type': 'artist',
#     'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5eTAmV8stngDTcO4veqyVK'},
#   'href': 'https://api.spotify.com/v1/albums/5eTAmV8stngDTcO4veqyVK',
#   'id': '5eTAmV8stngDTcO4veqyVK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f221ae4798e902bf102e1bd2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f221ae4798e902bf102e1bd2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f221ae4798e902bf102e1bd2',
#     'width': 64}],
#   'name': 'Never Be Like You (feat. Kai)',
#   'release_date': '2016-01-16',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5eTAmV8stngDTcO4veqyVK'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#    'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#    'id': '6nxWCVXbOlEVRexSbLsTer',
#    'name': 'Flume',
#    'type': 'artist',
#    'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xHUXzrfhFgnIv86EBR3Ml'},
#    'href': 'https://api.spotify.com/v1/artists/6xHUXzrfhFgnIv86EBR3Ml',
#    'id': '6xHUXzrfhFgnIv86EBR3Ml',
#    'name': 'kai',
#    'type': 'artist',
#    'uri': 'spotify:artist:6xHUXzrfhFgnIv86EBR3Ml'}],
#  'available_markets': [],
#  'disc_number': 1,
#  'duration_ms': 234909,
#  'explicit': True,
#  'external_ids': {'isrc': 'AUFF01500784'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6y0igZArWVi6Iz0rj35c1Y'},
#  'href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'is_local': False,
#  'name': 'Never Be Like You (feat. Kai)',
#  'popularity': 0,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y'}

# %%
playlist_id = '7MyyVCzxJdnUM5gW2zBoUS'
playlist = requests.get(BASE_URL + 'playlists/' + playlist_id, headers=headers)

# %%
playlist = playlist.json()
playlist
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/7MyyVCzxJdnUM5gW2zBoUS'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/7MyyVCzxJdnUM5gW2zBoUS',
#  'id': '7MyyVCzxJdnUM5gW2zBoUS',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730043938cbfedf46fc0faf7ceab67616d0000b2732667b1d81f4313b1794f3178ab67616d0000b27375c4a22255cf08a01ba29597ab67616d0000b273ba2c7b2782c7aaf974167984',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730043938cbfedf46fc0faf7ceab67616d0000b2732667b1d81f4313b1794f3178ab67616d0000b27375c4a22255cf08a01ba29597ab67616d0000b273ba2c7b2782c7aaf974167984',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730043938cbfedf46fc0faf7ceab67616d0000b2732667b1d81f4313b1794f3178ab67616d0000b27375c4a22255cf08a01ba29597ab67616d0000b273ba2c7b2782c7aaf974167984',
#    'width': 60}],
#  'name': 'Liked Songs',
#  'owner': {'display_name': 'Suma Marri',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#   'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#   'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#   'type': 'user',
#   'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MywyMzk0MzliNmIxMmYyOTllNzQ4MTFiYTdhNzgwZWJmM2RkYTBiOThi',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/7MyyVCzxJdnUM5gW2zBoUS/tracks?offset=0&limit=100',
#   'items': [{'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rQoBDKFnd1n6BkdbgVaRL'},
#         'href': 'https://api.spotify.com/v1/artists/5rQoBDKFnd1n6BkdbgVaRL',
#         'id': '5rQoBDKFnd1n6BkdbgVaRL',
#         'name': 'Guru Randhawa',
#         'type': 'artist',
#         'uri': 'spotify:artist:5rQoBDKFnd1n6BkdbgVaRL'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3ZrZpzTnY2dG9j6deMtuRq'},
#       'href': 'https://api.spotify.com/v1/albums/3ZrZpzTnY2dG9j6deMtuRq',
#       'id': '3ZrZpzTnY2dG9j6deMtuRq',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27375c4a22255cf08a01ba29597',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0275c4a22255cf08a01ba29597',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485175c4a22255cf08a01ba29597',
#         'width': 64}],
#       'name': 'Ye Chota Nuvvunna (From "Saaho")',
#       'release_date': '2019-08-02',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:3ZrZpzTnY2dG9j6deMtuRq'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rQoBDKFnd1n6BkdbgVaRL'},
#        'href': 'https://api.spotify.com/v1/artists/5rQoBDKFnd1n6BkdbgVaRL',
#        'id': '5rQoBDKFnd1n6BkdbgVaRL',
#        'name': 'Guru Randhawa',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rQoBDKFnd1n6BkdbgVaRL'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0T1CMVkqffHlqEk4BcAph1'},
#        'href': 'https://api.spotify.com/v1/artists/0T1CMVkqffHlqEk4BcAph1',
#        'id': '0T1CMVkqffHlqEk4BcAph1',
#        'name': 'Tulsi Kumar',
#        'type': 'artist',
#        'uri': 'spotify:artist:0T1CMVkqffHlqEk4BcAph1'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1QvyquqkuuwUzdszyoKIy4'},
#        'href': 'https://api.spotify.com/v1/artists/1QvyquqkuuwUzdszyoKIy4',
#        'id': '1QvyquqkuuwUzdszyoKIy4',
#        'name': 'Haricharan',
#        'type': 'artist',
#        'uri': 'spotify:artist:1QvyquqkuuwUzdszyoKIy4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 194551,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS181904296'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/499rs8fMaltXk2BOlq9P0m'},
#      'href': 'https://api.spotify.com/v1/tracks/499rs8fMaltXk2BOlq9P0m',
#      'id': '499rs8fMaltXk2BOlq9P0m',
#      'is_local': False,
#      'name': 'Ye Chota Nuvvunna (From "Saaho") (feat. Tulsi Kumar, Haricharan Seshadri)',
#      'popularity': 54,
#      'preview_url': 'https://p.scdn.co/mp3-preview/9104d3195c268999f136a676b4c6b4e6a3884c62?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:499rs8fMaltXk2BOlq9P0m'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#         'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#         'id': '5VVN3xZw1i2qihfITZlvCZ',
#         'name': 'G. V. Prakash',
#         'type': 'artist',
#         'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1suV5B0kYcyI1Dmgjcud3o'},
#       'href': 'https://api.spotify.com/v1/albums/1suV5B0kYcyI1Dmgjcud3o',
#       'id': '1suV5B0kYcyI1Dmgjcud3o',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273ba2c7b2782c7aaf974167984',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02ba2c7b2782c7aaf974167984',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851ba2c7b2782c7aaf974167984',
#         'width': 64}],
#       'name': 'Endukante Premanta',
#       'release_date': '2012-04-29',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:1suV5B0kYcyI1Dmgjcud3o'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QvyquqkuuwUzdszyoKIy4'},
#        'href': 'https://api.spotify.com/v1/artists/1QvyquqkuuwUzdszyoKIy4',
#        'id': '1QvyquqkuuwUzdszyoKIy4',
#        'name': 'Haricharan',
#        'type': 'artist',
#        'uri': 'spotify:artist:1QvyquqkuuwUzdszyoKIy4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IUtwMti1OiT3lkW6RubgH'},
#        'href': 'https://api.spotify.com/v1/artists/2IUtwMti1OiT3lkW6RubgH',
#        'id': '2IUtwMti1OiT3lkW6RubgH',
#        'name': 'K. S. Chithra',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IUtwMti1OiT3lkW6RubgH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 360000,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INA091213380'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2FPYJZygSLhD9RdPvEnBha'},
#      'href': 'https://api.spotify.com/v1/tracks/2FPYJZygSLhD9RdPvEnBha',
#      'id': '2FPYJZygSLhD9RdPvEnBha',
#      'is_local': False,
#      'name': 'Nee Choopule',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/91935929356527560858e8ede3684650212ffc1e?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:2FPYJZygSLhD9RdPvEnBha'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#         'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#         'id': '5sSzCxHtgL82pYDvx2QyEU',
#         'name': 'Devi Sri Prasad',
#         'type': 'artist',
#         'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5vVzgxWC3S6eiQ1a5rYvo0'},
#       'href': 'https://api.spotify.com/v1/albums/5vVzgxWC3S6eiQ1a5rYvo0',
#       'id': '5vVzgxWC3S6eiQ1a5rYvo0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2730043938cbfedf46fc0faf7ce',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e020043938cbfedf46fc0faf7ce',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048510043938cbfedf46fc0faf7ce',
#         'width': 64}],
#       'name': 'Khaidi No 150',
#       'release_date': '2017-01-05',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:5vVzgxWC3S6eiQ1a5rYvo0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65jsdEMz2d1jbIECHqAhFr'},
#        'href': 'https://api.spotify.com/v1/artists/65jsdEMz2d1jbIECHqAhFr',
#        'id': '65jsdEMz2d1jbIECHqAhFr',
#        'name': 'Jaspreet Jasz',
#        'type': 'artist',
#        'uri': 'spotify:artist:65jsdEMz2d1jbIECHqAhFr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269289,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS181602173'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/37qEgpLxOJN2jpxo2yEl64'},
#      'href': 'https://api.spotify.com/v1/tracks/37qEgpLxOJN2jpxo2yEl64',
#      'id': '37qEgpLxOJN2jpxo2yEl64',
#      'is_local': False,
#      'name': 'Sundari',
#      'popularity': 39,
#      'preview_url': 'https://p.scdn.co/mp3-preview/9ce15670948694e0ca1ae881998b5138b92f673e?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:37qEgpLxOJN2jpxo2yEl64'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#         'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#         'id': '5sSzCxHtgL82pYDvx2QyEU',
#         'name': 'Devi Sri Prasad',
#         'type': 'artist',
#         'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5vVzgxWC3S6eiQ1a5rYvo0'},
#       'href': 'https://api.spotify.com/v1/albums/5vVzgxWC3S6eiQ1a5rYvo0',
#       'id': '5vVzgxWC3S6eiQ1a5rYvo0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2730043938cbfedf46fc0faf7ce',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e020043938cbfedf46fc0faf7ce',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048510043938cbfedf46fc0faf7ce',
#         'width': 64}],
#       'name': 'Khaidi No 150',
#       'release_date': '2017-01-05',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:5vVzgxWC3S6eiQ1a5rYvo0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NoJ7NuNs9nyj8Thoh1kbu'},
#        'href': 'https://api.spotify.com/v1/artists/2NoJ7NuNs9nyj8Thoh1kbu',
#        'id': '2NoJ7NuNs9nyj8Thoh1kbu',
#        'name': 'Hariharan',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy'},
#        'href': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy',
#        'id': '0oOet2f43PA68X5RxKobEy',
#        'name': 'Shreya Ghoshal',
#        'type': 'artist',
#        'uri': 'spotify:artist:0oOet2f43PA68X5RxKobEy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 229320,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS181602189'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/008lRa3qOTxsZE3UeKW8yp'},
#      'href': 'https://api.spotify.com/v1/tracks/008lRa3qOTxsZE3UeKW8yp',
#      'id': '008lRa3qOTxsZE3UeKW8yp',
#      'is_local': False,
#      'name': 'You & Me',
#      'popularity': 46,
#      'preview_url': 'https://p.scdn.co/mp3-preview/bd03c1f44e60ccfc767731b0b5e77e4d62275d50?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:008lRa3qOTxsZE3UeKW8yp'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#         'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#         'id': '5sSzCxHtgL82pYDvx2QyEU',
#         'name': 'Devi Sri Prasad',
#         'type': 'artist',
#         'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3luAOiA8IWyuqcbh8eR8ui'},
#       'href': 'https://api.spotify.com/v1/albums/3luAOiA8IWyuqcbh8eR8ui',
#       'id': '3luAOiA8IWyuqcbh8eR8ui',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732667b1d81f4313b1794f3178',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022667b1d81f4313b1794f3178',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512667b1d81f4313b1794f3178',
#         'width': 64}],
#       'name': 'Kanthaswamy (Original Motion Picture Soundtrack)',
#       'release_date': '2009-05-07',
#       'release_date_precision': 'day',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:3luAOiA8IWyuqcbh8eR8ui'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#        'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#        'id': '5sSzCxHtgL82pYDvx2QyEU',
#        'name': 'Devi Sri Prasad',
#        'type': 'artist',
#        'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Z7tNWlrQnxjy4LuhlHAAB'},
#        'href': 'https://api.spotify.com/v1/artists/3Z7tNWlrQnxjy4LuhlHAAB',
#        'id': '3Z7tNWlrQnxjy4LuhlHAAB',
#        'name': 'Rita',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Z7tNWlrQnxjy4LuhlHAAB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 323440,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS170900195'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6lINfLttHSl6Q0uGyCFVsw'},
#      'href': 'https://api.spotify.com/v1/tracks/6lINfLttHSl6Q0uGyCFVsw',
#      'id': '6lINfLttHSl6Q0uGyCFVsw',
#      'is_local': False,
#      'name': 'Allegro',
#      'popularity': 44,
#      'preview_url': 'https://p.scdn.co/mp3-preview/2be408aa86ad9b30f3066c4279f1544474e8917c?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:6lINfLttHSl6Q0uGyCFVsw'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#         'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#         'id': '5sSzCxHtgL82pYDvx2QyEU',
#         'name': 'Devi Sri Prasad',
#         'type': 'artist',
#         'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3luAOiA8IWyuqcbh8eR8ui'},
#       'href': 'https://api.spotify.com/v1/albums/3luAOiA8IWyuqcbh8eR8ui',
#       'id': '3luAOiA8IWyuqcbh8eR8ui',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732667b1d81f4313b1794f3178',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022667b1d81f4313b1794f3178',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512667b1d81f4313b1794f3178',
#         'width': 64}],
#       'name': 'Kanthaswamy (Original Motion Picture Soundtrack)',
#       'release_date': '2009-05-07',
#       'release_date_precision': 'day',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:3luAOiA8IWyuqcbh8eR8ui'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#        'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#        'id': '5sSzCxHtgL82pYDvx2QyEU',
#        'name': 'Devi Sri Prasad',
#        'type': 'artist',
#        'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1hP2OKkJ24oEkW8nNpQLX7'},
#        'href': 'https://api.spotify.com/v1/artists/1hP2OKkJ24oEkW8nNpQLX7',
#        'id': '1hP2OKkJ24oEkW8nNpQLX7',
#        'name': 'Vikram',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hP2OKkJ24oEkW8nNpQLX7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3R0YzDT1gl2mMDLMrgdNjR'},
#        'href': 'https://api.spotify.com/v1/artists/3R0YzDT1gl2mMDLMrgdNjR',
#        'id': '3R0YzDT1gl2mMDLMrgdNjR',
#        'name': 'Suchitra',
#        'type': 'artist',
#        'uri': 'spotify:artist:3R0YzDT1gl2mMDLMrgdNjR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 346813,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS170900191'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4lGIy8N9aPgfUf04oFH2GS'},
#      'href': 'https://api.spotify.com/v1/tracks/4lGIy8N9aPgfUf04oFH2GS',
#      'id': '4lGIy8N9aPgfUf04oFH2GS',
#      'is_local': False,
#      'name': 'Excuse Me',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a457200a24cc8b36d46f3102c23150d3ecb35158?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4lGIy8N9aPgfUf04oFH2GS'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
# ...
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 252631,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS172101129'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0t0mHozF8Xsif9w8bemh9D'},
#      'href': 'https://api.spotify.com/v1/tracks/0t0mHozF8Xsif9w8bemh9D',
#      'id': '0t0mHozF8Xsif9w8bemh9D',
#      'is_local': False,
#      'name': 'So Baby (From "Doctor")',
#      'popularity': 68,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a4c20d1b5388edc5ec801dbdb4262766f9fa7ca0?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0t0mHozF8Xsif9w8bemh9D'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'},
#         'href': 'https://api.spotify.com/v1/artists/5FVBduYaeVBb6JIghza7v6',
#         'id': '5FVBduYaeVBb6JIghza7v6',
#         'name': 'Santhosh Narayanan',
#         'type': 'artist',
#         'uri': 'spotify:artist:5FVBduYaeVBb6JIghza7v6'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3jTx8LYOYIO0cRZDlS1uPx'},
#       'href': 'https://api.spotify.com/v1/albums/3jTx8LYOYIO0cRZDlS1uPx',
#       'id': '3jTx8LYOYIO0cRZDlS1uPx',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27303d07460c6880e35aa9129dd',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0203d07460c6880e35aa9129dd',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485103d07460c6880e35aa9129dd',
#         'width': 64}],
#       'name': 'Bujji (From "Jagame Thandhiram")',
#       'release_date': '2020-11-13',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:3jTx8LYOYIO0cRZDlS1uPx'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'},
#        'href': 'https://api.spotify.com/v1/artists/5FVBduYaeVBb6JIghza7v6',
#        'id': '5FVBduYaeVBb6JIghza7v6',
#        'name': 'Santhosh Narayanan',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FVBduYaeVBb6JIghza7v6'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#        'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#        'id': '4zCH9qm4R2DADamUHMCa6O',
#        'name': 'Anirudh Ravichander',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 267203,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS172004029'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6rJhjykEkCqm3H64uALhhf'},
#      'href': 'https://api.spotify.com/v1/tracks/6rJhjykEkCqm3H64uALhhf',
#      'id': '6rJhjykEkCqm3H64uALhhf',
#      'is_local': False,
#      'name': 'Bujji (From "Jagame Thandhiram")',
#      'popularity': 64,
#      'preview_url': 'https://p.scdn.co/mp3-preview/6dedb18403e6bc27fdb2f5690aa9e2fa330c1969?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6rJhjykEkCqm3H64uALhhf'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-03-27T05:22:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31k52b7pwjstcseyjnxnp72uwzbe'},
#      'href': 'https://api.spotify.com/v1/users/31k52b7pwjstcseyjnxnp72uwzbe',
#      'id': '31k52b7pwjstcseyjnxnp72uwzbe',
#      'type': 'user',
#      'uri': 'spotify:user:31k52b7pwjstcseyjnxnp72uwzbe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#         'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#         'id': '4zCH9qm4R2DADamUHMCa6O',
#         'name': 'Anirudh Ravichander',
#         'type': 'artist',
#         'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7sVOaTioI70p4A36YtSDbY'},
#       'href': 'https://api.spotify.com/v1/albums/7sVOaTioI70p4A36YtSDbY',
#       'id': '7sVOaTioI70p4A36YtSDbY',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2737f4758ab956193d0d3814a16',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e027f4758ab956193d0d3814a16',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048517f4758ab956193d0d3814a16',
#         'width': 64}],
#       'name': 'Doctor (Original Motion Picture Soundtrack)',
#       'release_date': '2021-10-05',
#       'release_date_precision': 'day',
#       'total_tracks': 4,
#       'type': 'album',
#       'uri': 'spotify:album:7sVOaTioI70p4A36YtSDbY'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#        'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#        'id': '4zCH9qm4R2DADamUHMCa6O',
#        'name': 'Anirudh Ravichander',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 256500,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'INS172002832'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6bUHZRZ4YpVxB1RWrPH5dh'},
#      'href': 'https://api.spotify.com/v1/tracks/6bUHZRZ4YpVxB1RWrPH5dh',
#      'id': '6bUHZRZ4YpVxB1RWrPH5dh',
#      'is_local': False,
#      'name': 'Nenjame',
#      'popularity': 56,
#      'preview_url': 'https://p.scdn.co/mp3-preview/f489fec1643293291077aa2fb6ba00a5492aaaf1?cid=fcec7bdbea3d438f9a0b9158e82b057f',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:6bUHZRZ4YpVxB1RWrPH5dh'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': 'https://api.spotify.com/v1/playlists/7MyyVCzxJdnUM5gW2zBoUS/tracks?offset=100&limit=100',
#   'offset': 0,
#   'previous': None,
#   'total': 302},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:7MyyVCzxJdnUM5gW2zBoUS'}

# %%
import numpy as np
import pandas as pd
import json

# %%
pd.json_normalize(playlist)
# Out:
#    collaborative description  \
# 0          False
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...  7MyyVCzxJdnUM5gW2zBoUS
#
#                                               images         name  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...  Liked Songs
#
#   primary_color  public                                        snapshot_id  \
# 0          None    True  MywyMzk0MzliNmIxMmYyOTllNzQ4MTFiYTdhNzgwZWJmM2...
#
#        type  ...                      owner.id owner.type  \
# 0  playlist  ...  31k52b7pwjstcseyjnxnp72uwzbe       user
#
#                                    owner.uri  \
# 0  spotify:user:31k52b7pwjstcseyjnxnp72uwzbe
#
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...
#
#                                         tracks.items tracks.limit  \
# 0  [{'added_at': '2022-03-27T05:22:24Z', 'added_b...          100
#
#                                          tracks.next tracks.offset  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...             0
#
#   tracks.previous tracks.total
# 0            None          302
#
# [1 rows x 27 columns]

# %%
df.head()
# Out:
#    collaborative description  \
# 0          False
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...  7MyyVCzxJdnUM5gW2zBoUS
#
#                                               images         name  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...  Liked Songs
#
#   primary_color  public                                        snapshot_id  \
# 0          None    True  MywyMzk0MzliNmIxMmYyOTllNzQ4MTFiYTdhNzgwZWJmM2...
#
#        type  ...                      owner.id owner.type  \
# 0  playlist  ...  31k52b7pwjstcseyjnxnp72uwzbe       user
#
#                                    owner.uri  \
# 0  spotify:user:31k52b7pwjstcseyjnxnp72uwzbe
#
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...
#
#                                         tracks.items tracks.limit  \
# 0  [{'added_at': '2022-03-27T05:22:24Z', 'added_b...          100
#
#                                          tracks.next tracks.offset  \
# 0  https://api.spotify.com/v1/playlists/7MyyVCzxJ...             0
#
#   tracks.previous tracks.total
# 0            None          302
#
# [1 rows x 27 columns]
