# %%
#Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
from sklearn import svm
# %matplotlib inline

# %%
playlist1_df = pd.read_csv("Datasets/MusicTaste/SumaSpotifyMusicTaste.csv")
playlist1_df.shape
# Out:
# (256, 18)

# %%
playlist2_df = pd.read_csv("Datasets/MusicTaste/TestSpotifyMusicTaste.csv")
playlist2_df.shape
# Out:
# (234, 18)

# %%
playlist1_df.head()
# Out:
#    Unnamed: 0                      id  \
# 0           0  499rs8fMaltXk2BOlq9P0m
# 1           1  2FPYJZygSLhD9RdPvEnBha
# 2           2  37qEgpLxOJN2jpxo2yEl64
# 3           3  008lRa3qOTxsZE3UeKW8yp
# 4           4  6lINfLttHSl6Q0uGyCFVsw
#
#                                                 name  popularity  \
# 0  Ye Chota Nuvvunna (From "Saaho") (feat. Tulsi ...        54.0
# 1                                       Nee Choopule        52.0
# 2                                            Sundari        39.0
# 3                                           You & Me        46.0
# 4                                            Allegro        44.0
#
#    track_number                                   uri  danceability  energy  \
# 0           1.0  spotify:track:499rs8fMaltXk2BOlq9P0m         0.725   0.675
# 1           2.0  spotify:track:2FPYJZygSLhD9RdPvEnBha         0.573   0.350
# 2           2.0  spotify:track:37qEgpLxOJN2jpxo2yEl64         0.866   0.860
# 3           3.0  spotify:track:008lRa3qOTxsZE3UeKW8yp         0.840   0.715
# 4           5.0  spotify:track:6lINfLttHSl6Q0uGyCFVsw         0.776   0.804
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -6.225       0.0444        0.1160          0.000044    0.0990   0.6410
# 1    -8.126       0.0260        0.2620          0.000017    0.0976   0.0386
# 2    -3.662       0.0552        0.1850          0.000086    0.0629   0.8990
# 3    -4.307       0.0836        0.2000          0.014500    0.1030   0.7360
# 4    -3.274       0.1100        0.0526          0.013100    0.0707   0.7600
#
#      tempo                                 artists  \
# 0   92.017  Guru Randhawa, Tulsi Kumar, Haricharan
# 1   90.925               Haricharan, K. S. Chithra
# 2  101.982                           Jaspreet Jasz
# 3  118.988               Hariharan, Shreya Ghoshal
# 4  105.051                   Devi Sri Prasad, Rita
#
#                                               album release_date
# 0                  Ye Chota Nuvvunna (From "Saaho")   2019-08-02
# 1                                Endukante Premanta   2012-04-29
# 2                                     Khaidi No 150   2017-01-05
# 3                                     Khaidi No 150   2017-01-05
# 4  Kanthaswamy (Original Motion Picture Soundtrack)   2009-05-07

# %%
playlist2_df.head()
# Out:
#    Unnamed: 0                      id              name  popularity  \
# 0         188  3ipHW5XTIQ5CtNWEurXuOI       Davva Davva          17
# 1         345  4Enr48UdAmBWn6PLgSLsqS         Anaganaga          20
# 2         492  0kz3Bh09Li3wtcreZV3BKM     Follow Follow          22
# 3         406  0MqVQMkcEdJQ2cnFOOdrSk             Koova          29
# 4         425  0LMvYrD1JpHavQcyRoSaqZ  Beat In My Heart          33
#
#    track_number                                   uri  danceability  energy  \
# 0             1  spotify:track:3ipHW5XTIQ5CtNWEurXuOI         0.745   0.703
# 1             1  spotify:track:4Enr48UdAmBWn6PLgSLsqS         0.753   0.530
# 2             1  spotify:track:0kz3Bh09Li3wtcreZV3BKM         0.829   0.781
# 3             1  spotify:track:0MqVQMkcEdJQ2cnFOOdrSk         0.940   0.696
# 4             1  spotify:track:0LMvYrD1JpHavQcyRoSaqZ         0.706   0.832
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -5.947       0.0440       0.18000          0.000312    0.0426    0.660
# 1    -8.851       0.0429       0.40900          0.007080    0.1340    0.425
# 2    -4.137       0.0770       0.31700          0.016500    0.0866    0.965
# 3    -5.991       0.1130       0.05510          0.000007    0.6120    0.782
# 4    -5.260       0.0750       0.00711          0.000038    0.0863    0.565
#
#      tempo                artists  \
# 0   90.025           Armaan Malik
# 1  130.020        Ambika Sashital
# 2   94.017        Devi Sri Prasad
# 3  126.923  Karthik, Chinna Ponnu
# 4  128.598  Nagoor Babu, Gayathri
#
#                                                album release_date
# 0                                              Rider    3/10/2022
# 1                                         Goodachari    7/23/2018
# 2  Nannaku Prematho (Original Motion Picture Soun...   12/25/2015
# 3                                  Ondraga Originals    1/14/2018
# 4                                             Gulabi    2/19/1995

# %% [markdown]
# equaling data

# %%
playlist1_df.count
# Out:
# <bound method DataFrame.count of      Unnamed: 0                      id  \
# 0             0  499rs8fMaltXk2BOlq9P0m
# 1             1  2FPYJZygSLhD9RdPvEnBha
# 2             2  37qEgpLxOJN2jpxo2yEl64
# 3             3  008lRa3qOTxsZE3UeKW8yp
# 4             4  6lINfLttHSl6Q0uGyCFVsw
# ..          ...                     ...
# 251         587  6rji5mwjuHRuhozNhn8DG8
# 252         588  7zEqY4oGrTVOx85VlRSymi
# 253         589  05dYneZZZ2mytSmnsvzFoW
# 254         590  7crGzxRqI5pMZAjZgF9uu2
# 255         591  5fqsWynhQRpoIVeRfRu4yQ
#
#                                                   name  popularity  \
# 0    Ye Chota Nuvvunna (From "Saaho") (feat. Tulsi ...        54.0
# 1                                         Nee Choopule        52.0
# 2                                              Sundari        39.0
# 3                                             You & Me        46.0
# 4                                              Allegro        44.0
# ..                                                 ...         ...
# 251                         Adhento Gaani Vunnapaatuga        55.0
# 252                                         Tamilselvi        54.0
# 253                                       Gangu Leader        57.0
# 254                       Jai Sulthan - From "Sulthan"        62.0
# 255                                      Un Vizhigalil        56.0
#
#      track_number                                   uri  danceability  energy  \
# 0             1.0  spotify:track:499rs8fMaltXk2BOlq9P0m         0.725   0.675
# 1             2.0  spotify:track:2FPYJZygSLhD9RdPvEnBha         0.573   0.350
# 2             2.0  spotify:track:37qEgpLxOJN2jpxo2yEl64         0.866   0.860
# 3             3.0  spotify:track:008lRa3qOTxsZE3UeKW8yp         0.840   0.715
# 4             5.0  spotify:track:6lINfLttHSl6Q0uGyCFVsw         0.776   0.804
# ..            ...                                   ...           ...     ...
# 251           1.0  spotify:track:6rji5mwjuHRuhozNhn8DG8         0.392   0.725
# 252           6.0  spotify:track:7zEqY4oGrTVOx85VlRSymi         0.696   0.931
# 253           4.0  spotify:track:05dYneZZZ2mytSmnsvzFoW         0.775   0.860
# 254           1.0  spotify:track:7crGzxRqI5pMZAjZgF9uu2         0.722   0.860
# 255           3.0  spotify:track:5fqsWynhQRpoIVeRfRu4yQ         0.502   0.625
#
#      loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      -6.225       0.0444        0.1160          0.000044    0.0990   0.6410
# 1      -8.126       0.0260        0.2620          0.000017    0.0976   0.0386
# 2      -3.662       0.0552        0.1850          0.000086    0.0629   0.8990
# 3      -4.307       0.0836        0.2000          0.014500    0.1030   0.7360
# 4      -3.274       0.1100        0.0526          0.013100    0.0707   0.7600
# ..        ...          ...           ...               ...       ...      ...
# 251    -5.103       0.0504        0.1230          0.000000    0.1930   0.3130
# 252    -4.089       0.0636        0.0798          0.000006    0.2340   0.8470
# 253    -5.869       0.2690        0.2880          0.000000    0.0514   0.6440
# 254    -3.713       0.2050        0.5370          0.000000    0.1140   0.8140
# 255    -5.631       0.0309        0.3790          0.000000    0.1980   0.4420
#
#        tempo                                            artists  \
# 0     92.017             Guru Randhawa, Tulsi Kumar, Haricharan
# 1     90.925                          Haricharan, K. S. Chithra
# 2    101.982                                      Jaspreet Jasz
# 3    118.988                          Hariharan, Shreya Ghoshal
# 4    105.051                              Devi Sri Prasad, Rita
# ..       ...                                                ...
# 251   78.453                                Anirudh Ravichander
# 252   89.972                   Anirudh Ravichander, Nakash Aziz
# 253  131.882                                Anirudh Ravichander
# 254   80.004  Vivek - Mervin, Anirudh Ravichander, Junior Ni...
# 255   80.217                 Anirudh Ravichander, Shruti Haasan
#
#                                                 album release_date
# 0                    Ye Chota Nuvvunna (From "Saaho")   2019-08-02
# 1                                  Endukante Premanta   2012-04-29
# 2                                       Khaidi No 150   2017-01-05
# 3                                       Khaidi No 150   2017-01-05
# 4    Kanthaswamy (Original Motion Picture Soundtrack)   2009-05-07
# ..                                                ...          ...
# 251                                            Jersey   2019-04-17
# 252         Remo (Original Motion Picture Soundtrack)   2016-09-05
# 253  Gang Leader (Original Motion Picture Soundtrack)   2019-09-05
# 254                      Jai Sulthan (From "Sulthan")   2021-02-11
# 255  Maan Karate (Original Motion Picture Soundtrack)   2014-03-16
#
# [256 rows x 18 columns]>

# %%
playlist2_df.count
# Out:
# <bound method DataFrame.count of      Unnamed: 0                      id                name  popularity  \
# 0           188  3ipHW5XTIQ5CtNWEurXuOI         Davva Davva          17
# 1           345  4Enr48UdAmBWn6PLgSLsqS           Anaganaga          20
# 2           492  0kz3Bh09Li3wtcreZV3BKM       Follow Follow          22
# 3           406  0MqVQMkcEdJQ2cnFOOdrSk               Koova          29
# 4           425  0LMvYrD1JpHavQcyRoSaqZ    Beat In My Heart          33
# ..          ...                     ...                 ...         ...
# 229         431  5PXmfhFNAxiqK86Xknc1HB           Darlingey          45
# 230         432  4KDq9bn0wdEbIFQDi1CGgj         Apudo Ipudo          61
# 231         500  2WO5nzB7QtKn9ZRc9Jkalt        Annul Maelae          64
# 232         161  5A6cWSeDqJqMwt2ylrVHko  Naan Dhaan Da Mass          48
# 233         474  4PML5RtrVcYAwTTS46otXB         Vaathi Raid          62
#
#      track_number                                   uri  danceability  energy  \
# 0               1  spotify:track:3ipHW5XTIQ5CtNWEurXuOI         0.745   0.703
# 1               1  spotify:track:4Enr48UdAmBWn6PLgSLsqS         0.753   0.530
# 2               1  spotify:track:0kz3Bh09Li3wtcreZV3BKM         0.829   0.781
# 3               1  spotify:track:0MqVQMkcEdJQ2cnFOOdrSk         0.940   0.696
# 4               1  spotify:track:0LMvYrD1JpHavQcyRoSaqZ         0.706   0.832
# ..            ...                                   ...           ...     ...
# 229             7  spotify:track:5PXmfhFNAxiqK86Xknc1HB         0.813   0.900
# 230             7  spotify:track:4KDq9bn0wdEbIFQDi1CGgj         0.880   0.711
# 231             7  spotify:track:2WO5nzB7QtKn9ZRc9Jkalt         0.773   0.436
# 232             8  spotify:track:5A6cWSeDqJqMwt2ylrVHko         0.655   0.809
# 233             8  spotify:track:4PML5RtrVcYAwTTS46otXB         0.806   0.930
#
#      loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      -5.947       0.0440       0.18000          0.000312    0.0426    0.660
# 1      -8.851       0.0429       0.40900          0.007080    0.1340    0.425
# 2      -4.137       0.0770       0.31700          0.016500    0.0866    0.965
# 3      -5.991       0.1130       0.05510          0.000007    0.6120    0.782
# 4      -5.260       0.0750       0.00711          0.000038    0.0863    0.565
# ..        ...          ...           ...               ...       ...      ...
# 229    -3.528       0.1450       0.17800          0.000121    0.2290    0.904
# 230    -9.529       0.1040       0.05190          0.002010    0.0667    0.819
# 231   -10.972       0.0321       0.67200          0.006780    0.1970    0.533
# 232    -6.634       0.1040       0.08120          0.000000    0.1850    0.559
# 233    -3.404       0.1320       0.25300          0.000019    0.1060    0.666
#
#        tempo                           artists  \
# 0     90.025                      Armaan Malik
# 1    130.020                   Ambika Sashital
# 2     94.017                   Devi Sri Prasad
# 3    126.923             Karthik, Chinna Ponnu
# 4    128.598             Nagoor Babu, Gayathri
# ..       ...                               ...
# 229  141.938   Devi Sri Prasad, Geetha Madhuri
# 230  102.986                         Siddharth
# 231  115.917  Harris Jayaraj, Sudha Ragunathan
# 232   85.023   Santhosh Narayanan, ofRO, Arivu
# 233  100.016        Anirudh Ravichander, Arivu
#
#                                                  album release_date
# 0                                                Rider    3/10/2022
# 1                                           Goodachari    7/23/2018
# 2    Nannaku Prematho (Original Motion Picture Soun...   12/25/2015
# 3                                    Ondraga Originals    1/14/2018
# 4                                               Gulabi    2/19/1995
# ..                                                 ...          ...
# 229                                             Mirchi     1/5/2013
# 230                                         Bommarillu    8/14/2006
# 231  Vaaranam Aayiram (Original Motion Picture Soun...    10/8/2008
# 232  Jagame Thandhiram (Original Motion Picture Sou...     6/7/2021
# 233        Master (Original Motion Picture Soundtrack)    3/16/2020
#
# [234 rows x 18 columns]>

# %%
# Create a dictionary in which the keys are the artists of my list and the values are the total of songs for each singer or group.
my_dict = dict(playlist1_df.artists.value_counts())
my_dict
# Out:
# {'Anirudh Ravichander': 9,
#  'S. P. Balasubrahmanyam, K. S. Chithra': 3,
#  'Sid Sriram': 3,
#  'Karthik': 3,
#  'Karthik, Chinmayi': 3,
#  'Yazin Nizar': 3,
#  'Guru Randhawa, Tulsi Kumar, Haricharan': 2,
#  'Prasanna.R, Hariharan, Mahathi': 2,
#  'Bombay Jayashri': 2,
#  'Dhibu Ninan Thomas, Kapil Kapilan': 2,
#  'Anirudh Ravichander, Jonita Gandhi': 2,
#  'Shweta Mohan': 2,
#  'Nikhita Gandhi': 2,
#  'Rahul Nambiar': 2,
#  'Devi Sri Prasad': 2,
#  'Anirudh Ravichander, Dhanush': 2,
#  'Karthik, K. S. Chithra': 2,
#  'Andrea Jeremiah': 2,
#  'Chinmayi': 2,
#  'Blaaze, Ranina Reddy, Devi Sri Prasad': 1,
#  'Sathyaprakash': 1,
#  'Sid Sriram, Shashaa Tirupati': 1,
#  'Karthik, Chinna Ponnu': 1,
#  'Narendra': 1,
#  'Sanjith Hegde, Karthik': 1,
#  'Shahil Hada, Chinmayi': 1,
#  'Anurag Kulkarni': 1,
#  'Anurag Kulkarni, Mickey J. Meyer': 1,
#  'Sid Sriram, Jonita Gandhi': 1,
#  'Harris Jayaraj, Shail Hada, Sudha Ragunathan, Andrea Jeremiah': 1,
#  'Leon James, Jonita Gandhi': 1,
#  'A.R. Rahman, Jonita Gandhi, Hriday Gattani': 1,
#  'Tippu, Salinisingh, Timmy': 1,
#  'KK, K. S. Chithra': 1,
#  'Sricharan Pakala': 1,
#  'Sunitha Sarathy, Febi Mani': 1,
#  'Sricharan Pakala, Yamini Ghantasala': 1,
#  'Chaitra, Santosh': 1,
#  'Anup Rubens, Smitha Belluri': 1,
#  'Chaitra': 1,
#  'A.R. Rahman, Mohit Chauhan, Shreya Ghoshal': 1,
#  'Yuvan Shankar Raja, Haricharan, Tanvi Shah': 1,
#  'Karthik, Shweta Mohan': 1,
#  'Yuvan Shankar Raja, Tanvi Shah': 1,
#  'Devi Sri Prasad, Suchitra, Tippu': 1,
#  'Sriram Parthasarathy': 1,
#  'Harris Jayaraj, Unnikrishnan, Chinmayi, Mega': 1,
#  'Sathursan, Varothayan, Ab1shanth, Rajithan': 1,
#  'Haricharan': 1,
#  'Harris Jayaraj': 1,
#  'Sid Sriram, Shreya Ghoshal': 1,
#  'Aaishwarya, Bhavya, Lakshmi, Gopi Sundar': 1,
#  'Harris Jayaraj, Clinton, S.P.Charan': 1,
#  'Karthik, Pranavi': 1,
#  'Siddharth, Sumangali': 1,
#  'Harris Jayaraj, Leslee Lewis, Jonita Gandhi': 1,
#  'Vishal-Shekhar, Arijit Singh, Shilpa Rao, Kumaar': 1,
#  'Hariharan, Harini': 1,
#  'Harris Jayaraj, Javed Ali, Darshana K.T.': 1,
#  'Harris Jayaraj, Karthik, Harini, Dr. Burn, Maya': 1,
#  'Karthik, Krishh, Harini': 1,
#  'Armaan Malik, Nikhita Gandhi, D. Imman': 1,
#  'Sanjith Hegde, Thurga': 1,
#  'A.R. Rahman, Raghav, Shilpa Rao, Gulzar': 1,
#  'Devi Sri Prasad, Geetha Madhuri': 1,
#  'Sam C.S., Sathyaprakash, Roshini': 1,
#  'Nagoor Babu, Gayathri': 1,
#  'Mani Sharma, Hemachandra Vedala, Shweta Mohan': 1,
#  'Mani Sharma, Ranjith Govind, Sravana Bhargavi': 1,
#  'Anirudh Ravichander, Gana Balachandar': 1,
#  'Deepak, Sravana Bhargavi': 1,
#  'Vijay Prakash, Neha Bhasin': 1,
#  'Jr. NTR': 1,
#  'Sooraj Santhosh': 1,
#  'Haricharan, Sadhana Sargam': 1,
#  'Harris Jayaraj, Krishh, Benny Dayal, Shruti Haasan': 1,
#  'Harris Jayaraj, Sudha Ragunathan': 1,
#  'Yuvan Shankar Raja, Karthik, Sunitha Sarathy': 1,
#  'Karthik, Bombay Jeyashree': 1,
#  'Anirudh Ravichander, Rokesh': 1,
#  'Anirudh Ravichander, Ravi G, Shashaa Tirupati': 1,
#  'Anirudh Ravichander, Adithya RK': 1,
#  'Anirudh Ravichander, Badshah': 1,
#  'Anirudh Ravichander, Dhanush, S. Janaki': 1,
#  'A.R. Rahman, Anirudh Ravichander, Neeti Mohan': 1,
#  'Hiphop Tamizha, Anirudh Ravichander': 1,
#  'Anirudh Ravichander, Pragathi': 1,
#  'Anirudh Ravichander, Justin Prabhakaran': 1,
#  'Anirudh Ravichander, Nakash Aziz': 1,
#  'Vivek - Mervin, Anirudh Ravichander, Junior Nithya, Gana Guna': 1,
#  'Mani Sharma, Karthik, Saindhavi': 1,
#  'Mani Sharma, Hemachandra Vedala, Malavika': 1,
#  'Mani Sharma, Ranjith Govind': 1,
#  'Ranjith Govind, Kalpana': 1,
#  'Mano, Eeshwar, K. S. Chithra': 1,
#  'Adnan Sami, Sunitha Rao': 1,
#  'Mano, K. S. Chithra': 1,
#  'Lalith Chilukuri': 1,
#  'Siddharth': 1,
#  'S. P. Balasubrahmanyam, S. Janaki': 1,
#  'S. P. Balasubrahmanyam': 1,
#  'Kunal Ganjawala, Shreya Ghoshal': 1,
#  'Devi Sri Prasad, KK': 1,
#  'Devi Sri Prasad, Baba Sehgal, Rita': 1,
#  'Vijay Prakash, Devan Ekambaram, D.Burn': 1,
#  'Mani Sharma, Ramesh Vinayakam, Karunya': 1,
#  'Dsp': 1,
#  'Neha Bhasin': 1,
#  'Sooraj Santhosh, M. M. Manasi': 1,
#  'Shankar Mahadevan, Gopika Poornima': 1,
#  'Adnan Sami': 1,
#  'Anirudh Ravichander, Arivu': 1,
#  'Keerthana Sharma, Saketh': 1,
#  'Armaan Malik, Sinduri Vishal': 1,
#  'Hemachandra Vedala': 1,
#  'Amit Trivedi, Shashaa Tirupati, Yazin Nizar': 1,
#  'Ambika Sashital': 1,
#  'Nihal': 1,
#  'Sachet Tandon, The Fusion Project': 1,
#  'Sachet Tandon, Sachet-Parampara': 1,
#  'Sachet Tandon, Nikhita Gandhi, Madhubanti Bagchi, Sachin-Jigar': 1,
#  'Bhoomi Trivedi, Raja Kumari, Ajay-Atul': 1,
#  'Sanjith Hegde': 1,
#  'Armaan Malik': 1,
#  'Armaan Malik, Arjun Janya': 1,
#  'Karthik, Megha': 1,
#  'Thaman S, Puneeth Rajkumar, Ramya Behra': 1,
#  'Thaman S, Armaan Malik, Shreya Ghoshal': 1,
#  'Vijay Prakash': 1,
#  'Shreya Ghoshal': 1,
#  'Thaman S, Nakash Aziz': 1,
#  'Anirudh Ravichander, Ananthakrrishnan': 1,
#  'Anivee, Amitash, Jonita Gandhi': 1,
#  'Alka Yagnik': 1,
#  'Alka Yagnik, Udit Narayan': 1,
#  'Vishal Dadlani': 1,
#  'Meet Bros Anjjan, Kanika Kapoor': 1,
#  'Arijit Singh, Aditi Singh Sharma': 1,
#  'Ankit Tiwari': 1,
#  'Atif Aslam, Sumedha Karmahe': 1,
#  'Santhosh Narayanan, Sid Sriram': 1,
#  'Anirudh Ravichander, Thalapathy Vijay': 1,
#  'Anirudh Ravichander, Vivek - Mervin': 1,
#  'Manan Bhardwaj': 1,
#  'Hiphop Tamizha, Nikhita Gandhi': 1,
#  'G. V. Prakash, Dhee': 1,
#  'A.R. Rahman, Nikhita Gandhi': 1,
#  'Jaspreet Jasz': 1,
#  'Hariharan, Shreya Ghoshal': 1,
#  'Devi Sri Prasad, Rita': 1,
#  'Devi Sri Prasad, Vikram, Suchitra': 1,
#  'Akhil Akkineni, Jonita Gandhi': 1,
#  'A.R. Rahman, Jonita Gandhi': 1,
#  'Sachin-Jigar, Vishal Dadlani, Jonita Gandhi': 1,
#  'A.R. Rahman, Sid Sriram, Shweta Mohan': 1,
#  'Sricharan Pakala, Anirudh Ravichander': 1,
#  'D. Imman, Luksimi Sivaneswaralingam': 1,
#  'M.M. Manasi, Sherin Shahana': 1,
#  'Bombay Jayashri, Haricharan': 1,
#  'Yuvan Shankar Raja, M.M. Manasi, Rubba Bend.Psycho Unit': 1,
#  'Anirudh Ravichander, Shruti Haasan, Shakthisree Gopalan': 1,
#  'Anirudh Ravichander, Shweta Mohan': 1,
#  'G. V. Prakash, S. P. Balasubrahmanyam, S.P.Charan, Prashanthini': 1,
#  'Santhosh Narayanan, ofRO, Arivu': 1,
#  'Anirudh Ravichander, Alisha Thomas': 1,
#  'Harris Jayaraj, Christopher Stanley, Abhay Jodhpurkar, Ujjayinee Roy': 1,
#  'Ranjith Govind, Geetha Madhuri': 1,
#  'Srinivas': 1,
#  'KK, Suchitra': 1,
#  'Anudeep Dev, Rahul': 1,
#  'Santhosh Narayanan, Dhanush, Dhee': 1,
#  'Dhee, Arivu, Santhosh Narayanan': 1,
#  'Asees Kaur, Ved Sharma': 1,
#  'KK, Sunitha': 1,
#  'Simha, Geetha Madhuri, Priya Hemesh': 1,
#  'Geetha Madhuri, Dhanunjay Seepana, Anudeep Dev, Arun': 1,
#  'Geetha Madhuri': 1,
#  'Sagar, Geetha Madhuri': 1,
#  'Vinayak, Sameera Bharadwaj': 1,
#  'Dhanunjay Seepana, Harini Ivvaturi': 1,
#  'Sri Krishna, Jaspreet Jasz, Hari Teja, Manisha Eerabathini, Ramya Behra': 1,
#  'Harini Ivvaturi': 1,
#  'Mika Singh, Prakriti Kakar': 1,
#  'Naim Almas': 1,
#  'Jonita Gandhi': 1,
#  'Shankar Mahadevan, Harini': 1,
#  'Leslee Lewis, Andrea Jeremiah, Vasundhara Das': 1,
#  'Tippu, Priya': 1,
#  'Tippu, Sunitha': 1,
#  'Karunya': 1,
#  'Karthik, Mahalakshmi Iyer': 1,
#  'Kunal Ganjawala': 1,
#  'Muralidar, Suchitra': 1,
#  'Haricharan, K. S. Chithra': 1,
#  'Ranjith Govind, Suchitra': 1,
#  'Naveen': 1,
#  'Ved Sharma': 1,
#  'M. M. Keeravani, Sunitha': 1,
#  'Brijesh Tripati Sandilya, Harini, Sunitha': 1,
#  'Anirudh Ravichander, Niranjana Ramanan': 1,
#  'Sam C.S., Anirudh Ravichander': 1,
#  'Thaman S, Srivardhini, Aditi Bhavaraju, Satya Yamini, Roshini JKV, Tejaswini': 1,
#  'KK': 1,
#  'Shankar Mahadevan, Shreya Ghoshal': 1,
#  'Rahul, Chours': 1,
#  'Ranjith Govind': 1,
#  'Armaan Malik, Shreya Ghoshal': 1,
#  'Rahul Nambiar, Sahithi Chaganti': 1,
#  'Harris Jayaraj, Sunitha Sarathy, Kharesma Ravichandran': 1,
#  'Harris Jayaraj, Karthik, Emcee Jesz': 1,
#  'L. V. Revanth, Sanjith Hegde, Hiphop Tamizha': 1,
#  'Hiphop Tamizha, Kharesma Ravichandran': 1,
#  'Hiphop Tamizha, Kaushik Krish, Padmalatha': 1,
#  'Hiphop Tamizha, Raghu Dixit, Sathyaprakash D., Jithin Raj': 1,
#  'Yuvan Shankar Raja, Benny Dayal': 1,
#  'Salimâ€“Sulaiman, Benny Dayal, Himani Kapoor, Amitabh Bhattacharya': 1,
#  'Benny Dayal, Priya': 1,
#  'Benny Dayal, Shreya Ghoshal': 1,
#  'Benny Dayal': 1,
#  'Benny Dayal, Neeti Mohan': 1,
#  'Vishal-Shekhar, Benny Dayal, Jaideep Sahni': 1,
#  'Salimâ€“Sulaiman, Benny Dayal, Amitabh Bhattacharya': 1,
#  'Pritam, Benny Dayal, Shefali Alvares': 1,
#  'Benny Dayal, Anmol Malik, Anu Malik': 1,
#  'Anirudh Ravichander, Shruti Haasan': 1}

# %%
# Create a temporary subset
temp_subset = playlist1_df

# %%
for k,v in my_dict.items(): 
    if v > 200 :
        drop_rows = 150
        drop_indexes_array = df_jhon[df_jhon.artist == k].sample(n = drop_rows).index
        temp_subset = temp_subset.drop(drop_indexes_array)
    elif v == 143 or v == 133 or v == 134:
        drop_rows = 60
        drop_indexes_array = df_jhon[df_jhon.artist == k].sample( n = drop_rows).index
        temp_subset = temp_subset.drop(drop_indexes_array)
    elif v ==178:
        drop_rows = 100
        drop_indexes_array = df_jhon[df_jhon.artist == k].sample(n = drop_rows).index
        temp_subset = temp_subset.drop(drop_indexes_array)

playlist1_df = temp_subset

# %%
playlist1_df.artists.count()
# Out:
# 256

# %%
# Setting new column to identify the users
playlist1_df['who'] = 1
playlist2_df['who'] = 2

# %%
# Combine both data frames 
df_couple = playlist1_df.append(playlist2_df)
df_couple.reset_index(inplace= True)
df_couple.drop('index', axis = 1, inplace= True)
df_couple.head()
# Out:
#    Unnamed: 0                      id  \
# 0           0  499rs8fMaltXk2BOlq9P0m
# 1           1  2FPYJZygSLhD9RdPvEnBha
# 2           2  37qEgpLxOJN2jpxo2yEl64
# 3           3  008lRa3qOTxsZE3UeKW8yp
# 4           4  6lINfLttHSl6Q0uGyCFVsw
#
#                                                 name  popularity  \
# 0  Ye Chota Nuvvunna (From "Saaho") (feat. Tulsi ...        54.0
# 1                                       Nee Choopule        52.0
# 2                                            Sundari        39.0
# 3                                           You & Me        46.0
# 4                                            Allegro        44.0
#
#    track_number                                   uri  danceability  energy  \
# 0           1.0  spotify:track:499rs8fMaltXk2BOlq9P0m         0.725   0.675
# 1           2.0  spotify:track:2FPYJZygSLhD9RdPvEnBha         0.573   0.350
# 2           2.0  spotify:track:37qEgpLxOJN2jpxo2yEl64         0.866   0.860
# 3           3.0  spotify:track:008lRa3qOTxsZE3UeKW8yp         0.840   0.715
# 4           5.0  spotify:track:6lINfLttHSl6Q0uGyCFVsw         0.776   0.804
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -6.225       0.0444        0.1160          0.000044    0.0990   0.6410
# 1    -8.126       0.0260        0.2620          0.000017    0.0976   0.0386
# 2    -3.662       0.0552        0.1850          0.000086    0.0629   0.8990
# 3    -4.307       0.0836        0.2000          0.014500    0.1030   0.7360
# 4    -3.274       0.1100        0.0526          0.013100    0.0707   0.7600
#
#      tempo                                 artists  \
# 0   92.017  Guru Randhawa, Tulsi Kumar, Haricharan
# 1   90.925               Haricharan, K. S. Chithra
# 2  101.982                           Jaspreet Jasz
# 3  118.988               Hariharan, Shreya Ghoshal
# 4  105.051                   Devi Sri Prasad, Rita
#
#                                               album release_date  who
# 0                  Ye Chota Nuvvunna (From "Saaho")   2019-08-02    1
# 1                                Endukante Premanta   2012-04-29    1
# 2                                     Khaidi No 150   2017-01-05    1
# 3                                     Khaidi No 150   2017-01-05    1
# 4  Kanthaswamy (Original Motion Picture Soundtrack)   2009-05-07    1

# %% [markdown]
# Comparing means

# %%
# Create data frame with features
def features(df,who):
    if who == 'both':
         features = df.loc[: ,['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence', 'who']]         
    elif who == 0 or who == 1:   
          features = df.loc[df.who == who,['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']]           
    else:
        return 'Error'
    return features

# %%
features1_df = features(df_couple, 1)
features2_df = features(df_couple,0)
features1_df.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  \
# 0        0.1160         0.725   0.675          0.000044    0.0990
# 1        0.2620         0.573   0.350          0.000017    0.0976
# 2        0.1850         0.866   0.860          0.000086    0.0629
# 3        0.2000         0.840   0.715          0.014500    0.1030
# 4        0.0526         0.776   0.804          0.013100    0.0707
#
#    speechiness  valence
# 0       0.0444   0.6410
# 1       0.0260   0.0386
# 2       0.0552   0.8990
# 3       0.0836   0.7360
# 4       0.1100   0.7600

# %%
playlist2_df.artists.value_counts()
# Out:
# Anirudh Ravichander                                        9
# Karthik                                                    3
# Yazin Nizar                                                3
# S. P. Balasubrahmanyam, K. S. Chithra                      3
# Chinmayi                                                   2
#                                                           ..
# Sanjith Hegde                                              1
# Tippu, Priya                                               1
# Sricharan Pakala, Yamini Ghantasala                        1
# Anirudh Ravichander, Shruti Haasan, Shakthisree Gopalan    1
# Anirudh Ravichander, Arivu                                 1
# Name: artists, Length: 209, dtype: int64

# %%
playlist1_df.artists.value_counts()
# Out:
# Anirudh Ravichander                                    9
# S. P. Balasubrahmanyam, K. S. Chithra                  3
# Sid Sriram                                             3
# Karthik                                                3
# Karthik, Chinmayi                                      3
#                                                       ..
# Vishal-Shekhar, Benny Dayal, Jaideep Sahni             1
# Salimâ€“Sulaiman, Benny Dayal, Amitabh Bhattacharya    1
# Pritam, Benny Dayal, Shefali Alvares                   1
# Benny Dayal, Anmol Malik, Anu Malik                    1
# Anirudh Ravichander, Shruti Haasan                     1
# Name: artists, Length: 225, dtype: int64

# %%
total_songs1 = playlist1_df.artists.count()
total_songs2 = playlist1_df.artists.count()
print(f'Total of songs:\nPerson 1: {playlist1_df.artists.count()}\nPerson 2:{playlist2_df.artists.count()}')
# Out:
# Total of songs:
# Person 1: 256
# Person 2:234

# %% [markdown]
# Data Analysis

# %%
# Number of features
N = len(features1_df.mean())
# Array with the number of features
ind = np.arange(N) 

width = 0.35  
#Bar plot with my list
plt.barh(ind, features1_df.mean() , width, label='Person 1', color = 'lightslategray')
#Bar plot with her list
plt.barh(ind + width, features2_df.mean(), width, label='Person 2', color = 'mediumvioletred')

#X- label
plt.xlabel('Mean', fontsize = 12)
# Title
plt.title('Mean values of the audio features')
#Vertical ticks
plt.yticks(ind + width / 2, (list(features2_df)[:]), fontsize = 12)
#legend
plt.legend(loc='best')
# Figure size
plt.rcParams['figure.figsize'] =(8,8)
# Set style
style.use("ggplot")

plt.show()
